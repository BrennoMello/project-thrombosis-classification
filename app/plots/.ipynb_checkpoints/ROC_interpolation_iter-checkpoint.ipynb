# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

# %%
plt.style.use('ggplot')

# %%
def plot_roc_curve_from_df(df):
    
    mean_fpr = np.linspace(0, 1, 100)
    fig, ax = plt.subplots(figsize=(10,7))

    list_models = df['model_name'].unique()

    for nmodel in list_models:

        df_filter = df[df.model_name == nmodel]
        tprs = []
        aucs = []

        for index, row in df_filter.iterrows():
            x = row['FPR'].replace('\n', '')
            y = row['TPR'].replace('\n', '')

            x = x.replace('[', '')
            y = y.replace('[', '')

            x = x.replace(']', '')
            y = y.replace(']', '')

            x = np.fromstring(x, dtype=float, sep=' ')
            y = np.fromstring(y, dtype=float, sep=' ')

            interp_tpr = np.interp(mean_fpr, x, y)
            interp_tpr[0] = 0.0
            tprs.append(interp_tpr)
            aucs.append(row['AUC'])

        mean_tpr = np.mean(tprs, axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)

        ax.plot(
            mean_fpr,
            mean_tpr,
            '--',
            label=r"Mean ROC (%0.25s AUC = %0.2f $\pm$ %0.2f)" % (nmodel, mean_auc, std_auc),
            lw=2,
            alpha=0.8,
        )

    ax.plot([0, 1], [0, 1], linestyle="-", lw=3, color="r", alpha=0.8)
    plt.xlabel("False Positive Rate", fontsize=16)
    plt.ylabel("True Positive Rate", fontsize=16)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    ax.legend()
    #ax.legend(loc="lower right")
    # cemter left
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    # 
    #ax.legend(bbox_to_anchor =(0.65, 1.25))

    plt.show()

# %%
path_results = '../results/all-results/'

# %% [markdown]
# ## A_thrombosis_non_thrombosis_v5

# %%
dset = 'A_thrombosis_non_thrombosis_v5'
test_size = 0.1
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'A_thrombosis_non_thrombosis_v5'
test_size = 0.15
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'A_thrombosis_non_thrombosis_v5'
test_size = 0.2
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %% [markdown]
# ## B_type_I_PE_vs_Type_II_v4

# %%
dset = 'B_type_I_PE_vs_Type_II_v4'
test_size = 0.1
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'B_type_I_PE_vs_Type_II_v4'
test_size = 0.15
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'B_type_I_PE_vs_Type_II_v4'
test_size = 0.2
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %% [markdown]
# ## C_type_I_vs_Type_II_no_PE_v4

# %%
dset = 'C_type_I_vs_Type_II_no_PE_v4'
test_size = 0.1
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
df_oc = dataf[dataf['model_name'] == 'OneClassSVM']
df_oc.describe()
# Out:
#        iteration         F1        ROC  acc-class-1  acc-class-2        SEN  \
# count   50.00000  50.000000  50.000000    50.000000    42.000000  50.000000
# mean    24.50000   0.876190   0.903333     0.900000     0.988095   0.993333
# std     14.57738   0.252029   0.193693     0.195615     0.077152   0.047140
# min      0.00000   0.333330   0.500000     0.500000     0.500000   0.666670
# 25%     12.25000   1.000000   1.000000     1.000000     1.000000   1.000000
# 50%     24.50000   1.000000   1.000000     1.000000     1.000000   1.000000
# 75%     36.75000   1.000000   1.000000     1.000000     1.000000   1.000000
# max     49.00000   1.000000   1.000000     1.000000     1.000000   1.000000
#
#              SPE        MCC        AUC
# count  50.000000  50.000000  50.000000
# mean    0.813333   0.808284   0.031111
# std     0.375919   0.386872   0.095344
# min     0.000000   0.000000   0.000000
# 25%     1.000000   1.000000   0.000000
# 50%     1.000000   1.000000   0.000000
# 75%     1.000000   1.000000   0.000000
# max     1.000000   1.000000   0.333333

# %%
dset = 'C_type_I_vs_Type_II_no_PE_v4'
test_size = 0.15
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'C_type_I_vs_Type_II_no_PE_v4'
test_size = 0.2
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %% [markdown]
# ## D_type_I_vs_type_II_v4

# %%
dset = 'D_type_I_vs_type_II_v4_roc'
test_size = 0.1
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'D_type_I_vs_type_II_v4_roc'
test_size = 0.15
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)

# %%
dset = 'D_type_I_vs_type_II_v4_roc'
test_size = 0.2
dataf = pd.read_csv(f'{path_results}{dset}_{test_size}.csv')
plot_roc_curve_from_df(dataf)
